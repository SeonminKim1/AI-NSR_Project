# %% [markdown]
# ## Predict bin_op1
# - <b>학습 모델 (gcc6_bincore_s32_h48_o1.h5) - binutils, coreutils 함수 시작점부터 32byte씩 hidden unit 48 개씩 최적화 O1 학습모델</b>
# - <b>테스트 bin_op01 , stirp 파일 각 EXE 파일들</b>

# %%
# model load
def load_trained_model(model_path):
    model = load_model(model_path)
    print('model load 완료')
    return model

# %%
def eval_load(data_path, file_name, model_sequence_length):
    # data load
    print('1. test data_load start')
    data = pd.read_csv(data_path + file_name, index_col=0)
    data.reset_index(inplace=True, drop=True)
    print('2. input data load and reset_index finish')

    # input sequence 로 나눔, 맨 뒤 나머지 빼기
    rest = len(data) % (model_sequence_length)
    print('3. rest data : ', rest)
    
    # 가짜 데이터 추가
    n = model_sequence_length - rest
    k = pd.DataFrame(columns=['bin','label'], data={'bin':[0]*n,'label':['0']*n})
    data = data.append(k)
    
    # data_sub_rest = data[:len(data) - rest]
    print('4. subtracting the rest finish', data.shape)

    # one hot encoding
#    encoder = LabelEncoder()
#    encoder.classes_ = 256
#    print('encoder.classes_', encoder.classes_)
#    data_onehot = encoder.fit_transform(data['bin'])
    data_onehot = pd.get_dummies(data['bin'], columns=np.arange(256))
    
    none_column = list(set(np.arange(256)).difference(set(data_onehot.columns)))
    for j in none_column:
    #    print(j)
        data_onehot[str(j)] = 0
    
    print('5. one hot encoding finish', data_onehot.shape)
    print(type(data_onehot), data_onehot.shape)
    
    data_ndarray = data_onehot.to_numpy() # data numpy 변환
    print('6. Transforming ndarray data finish', data_ndarray.shape)
    print('7. before reshape data shape', data_ndarray.shape)
    data_reshape = data_ndarray.reshape(-1, model_sequence_length, data_ndarray.shape[1])
    print('8. after reshape data shape', data_reshape.shape)
    print('9. test file load 완료')
    
    # reshape 된 data return
    return data_reshape, data, n

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder

# 파일 path 경로
model_path = 'model/gcc6_bincore_s32_h48_o1.h5'
data_path = 'data/strip/strip_gcc6_O1/'

import os
exe_file_list=os.listdir(data_path)
print("exe_file_list:{}".format(exe_file_list),'\n')

# model load
model = load_model(model_path)

# load test
for name in exe_file_list:
    test_data, data, n = eval_load(data_path, file_name=name, model_sequence_length=32)
    print('== ', name, '파일 predict 시작 ==')
    # model 모형 체크 및 데이터 read 체크
    model.summary()
    print('test_data.shape', test_data.shape)

    # model predict
    pr = model.predict(test_data)
    print('predict 완료')

    pr_ls = list(pr.flatten())
    print('전체 predict 정답 길이', len(pr_ls))
    pr_ls = list(map(lambda x:np.round(x), pr_ls))

    # 최종결과 데이터 
    result_data = pd.DataFrame(columns=['bin','label'])
    result_data['bin'] = data['bin'][:len(data)-n]
    result_data['label'] = pr_ls[:len(data)-n]

    # 다시 가짜 데이터 제거 후 최종 csv
    print('가짜 데이터 다시 제거 후 최종 csv shape', result_data.shape)
    result_data.to_csv('predict_result/bin_op1/'+name[:-4]+'_predict_result_op1.csv')
    print(name+'파일 csv저장 완료 \n\n')
# Out:
# exe_file_list:['addr2line_test_str.csv', 'ar_test_str.csv', 'as-new_test_str.csv', 'bfdtest1_test_str.csv', 'bfdtest2_test_str.csv', 'chew_test_str.csv', 'cxxfilt_test_str.csv', 'elfedit_test_str.csv', 'gentestdlls_test_str.csv', 'gprof_test_str.csv', 'ld-new_test_str.csv', 'nm-new_test_str.csv', 'objcopy_test_str.csv', 'objdump_test_str.csv', 'ranlib_test_str.csv', 'readelf_test_str.csv', 'size_test_str.csv', 'strings_test_str.csv', 'strip-new_test_str.csv', 'sysinfo_test_str.csv']
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  1
# 4. subtracting the rest finish (1076416, 2)
# 5. one hot encoding finish (1076416, 256)
# <class 'pandas.core.frame.DataFrame'> (1076416, 256)
# 6. Transforming ndarray data finish (1076416, 256)
# 7. before reshape data shape (1076416, 256)
# 8. after reshape data shape (33638, 32, 256)
# 9. test file load 완료
# ==  addr2line_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33638, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1076416
# 가짜 데이터 다시 제거 후 최종 csv shape (1076385, 2)
# addr2line_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1114464, 2)
# 5. one hot encoding finish (1114464, 256)
# <class 'pandas.core.frame.DataFrame'> (1114464, 256)
# 6. Transforming ndarray data finish (1114464, 256)
# 7. before reshape data shape (1114464, 256)
# 8. after reshape data shape (34827, 32, 256)
# 9. test file load 완료
# ==  ar_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34827, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1114464
# 가짜 데이터 다시 제거 후 최종 csv shape (1114441, 2)
# ar_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  25
# 4. subtracting the rest finish (1818240, 2)
# 5. one hot encoding finish (1818240, 256)
# <class 'pandas.core.frame.DataFrame'> (1818240, 256)
# 6. Transforming ndarray data finish (1818240, 256)
# 7. before reshape data shape (1818240, 256)
# 8. after reshape data shape (56820, 32, 256)
# 9. test file load 완료
# ==  as-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (56820, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1818240
# 가짜 데이터 다시 제거 후 최종 csv shape (1818233, 2)
# as-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1057120, 2)
# 5. one hot encoding finish (1057120, 256)
# <class 'pandas.core.frame.DataFrame'> (1057120, 256)
# 6. Transforming ndarray data finish (1057120, 256)
# 7. before reshape data shape (1057120, 256)
# 8. after reshape data shape (33035, 32, 256)
# 9. test file load 완료
# ==  bfdtest1_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33035, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1057120
# 가짜 데이터 다시 제거 후 최종 csv shape (1057097, 2)
# bfdtest1_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  29
# 4. subtracting the rest finish (1057216, 2)
# 5. one hot encoding finish (1057216, 256)
# <class 'pandas.core.frame.DataFrame'> (1057216, 256)
# 6. Transforming ndarray data finish (1057216, 256)
# 7. before reshape data shape (1057216, 256)
# 8. after reshape data shape (33038, 32, 256)
# 9. test file load 완료
# ==  bfdtest2_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33038, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1057216
# 가짜 데이터 다시 제거 후 최종 csv shape (1057213, 2)
# bfdtest2_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  10
# 4. subtracting the rest finish (21664, 2)
# 5. one hot encoding finish (21664, 256)
# <class 'pandas.core.frame.DataFrame'> (21664, 256)
# 6. Transforming ndarray data finish (21664, 256)
# 7. before reshape data shape (21664, 256)
# 8. after reshape data shape (677, 32, 256)
# 9. test file load 완료
# ==  chew_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (677, 32, 256)
# predict 완료
# 전체 predict 정답 길이 21664
# 가짜 데이터 다시 제거 후 최종 csv shape (21642, 2)
# chew_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  25
# 4. subtracting the rest finish (1075552, 2)
# 5. one hot encoding finish (1075552, 256)
# <class 'pandas.core.frame.DataFrame'> (1075552, 256)
# 6. Transforming ndarray data finish (1075552, 256)
# 7. before reshape data shape (1075552, 256)
# 8. after reshape data shape (33611, 32, 256)
# 9. test file load 완료
# ==  cxxfilt_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33611, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1075552
# 가짜 데이터 다시 제거 후 최종 csv shape (1075545, 2)
# cxxfilt_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  6
# 4. subtracting the rest finish (40032, 2)
# 5. one hot encoding finish (40032, 256)
# <class 'pandas.core.frame.DataFrame'> (40032, 256)
# 6. Transforming ndarray data finish (40032, 256)
# 7. before reshape data shape (40032, 256)
# 8. after reshape data shape (1251, 32, 256)
# 9. test file load 완료
# ==  elfedit_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (1251, 32, 256)
# predict 완료
# 전체 predict 정답 길이 40032
# 가짜 데이터 다시 제거 후 최종 csv shape (40006, 2)
# elfedit_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  28
# 4. subtracting the rest finish (6400, 2)
# 5. one hot encoding finish (6400, 256)
# <class 'pandas.core.frame.DataFrame'> (6400, 256)
# 6. Transforming ndarray data finish (6400, 256)
# 7. before reshape data shape (6400, 256)
# 8. after reshape data shape (200, 32, 256)
# 9. test file load 완료
# ==  gentestdlls_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (200, 32, 256)
# predict 완료
# 전체 predict 정답 길이 6400
# 가짜 데이터 다시 제거 후 최종 csv shape (6396, 2)
# gentestdlls_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1159968, 2)
# 5. one hot encoding finish (1159968, 256)
# <class 'pandas.core.frame.DataFrame'> (1159968, 256)
# 6. Transforming ndarray data finish (1159968, 256)
# 7. before reshape data shape (1159968, 256)
# 8. after reshape data shape (36249, 32, 256)
# 9. test file load 완료
# ==  gprof_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (36249, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1159968
# 가짜 데이터 다시 제거 후 최종 csv shape (1159949, 2)
# gprof_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  5
# 4. subtracting the rest finish (1869952, 2)
# 5. one hot encoding finish (1869952, 256)
# <class 'pandas.core.frame.DataFrame'> (1869952, 256)
# 6. Transforming ndarray data finish (1869952, 256)
# 7. before reshape data shape (1869952, 256)
# 8. after reshape data shape (58436, 32, 256)
# 9. test file load 완료
# ==  ld-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (58436, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1869952
# 가짜 데이터 다시 제거 후 최종 csv shape (1869925, 2)
# ld-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  1
# 4. subtracting the rest finish (1095360, 2)
# 5. one hot encoding finish (1095360, 256)
# <class 'pandas.core.frame.DataFrame'> (1095360, 256)
# 6. Transforming ndarray data finish (1095360, 256)
# 7. before reshape data shape (1095360, 256)
# 8. after reshape data shape (34230, 32, 256)
# 9. test file load 완료
# ==  nm-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34230, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1095360
# 가짜 데이터 다시 제거 후 최종 csv shape (1095329, 2)
# nm-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1256128, 2)
# 5. one hot encoding finish (1256128, 256)
# <class 'pandas.core.frame.DataFrame'> (1256128, 256)
# 6. Transforming ndarray data finish (1256128, 256)
# 7. before reshape data shape (1256128, 256)
# 8. after reshape data shape (39254, 32, 256)
# 9. test file load 완료
# ==  objcopy_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (39254, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1256128
# 가짜 데이터 다시 제거 후 최종 csv shape (1256109, 2)
# objcopy_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (2175008, 2)
# 5. one hot encoding finish (2175008, 256)
# <class 'pandas.core.frame.DataFrame'> (2175008, 256)
# 6. Transforming ndarray data finish (2175008, 256)
# 7. before reshape data shape (2175008, 256)
# 8. after reshape data shape (67969, 32, 256)
# 9. test file load 완료
# ==  objdump_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (67969, 32, 256)
# predict 완료
# 전체 predict 정답 길이 2175008
# 가짜 데이터 다시 제거 후 최종 csv shape (2174985, 2)
# objdump_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1114464, 2)
# 5. one hot encoding finish (1114464, 256)
# <class 'pandas.core.frame.DataFrame'> (1114464, 256)
# 6. Transforming ndarray data finish (1114464, 256)
# 7. before reshape data shape (1114464, 256)
# 8. after reshape data shape (34827, 32, 256)
# 9. test file load 완료
# ==  ranlib_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34827, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1114464
# 가짜 데이터 다시 제거 후 최종 csv shape (1114441, 2)
# ranlib_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1045984, 2)
# 5. one hot encoding finish (1045984, 256)
# <class 'pandas.core.frame.DataFrame'> (1045984, 256)
# 6. Transforming ndarray data finish (1045984, 256)
# 7. before reshape data shape (1045984, 256)
# 8. after reshape data shape (32687, 32, 256)
# 9. test file load 완료
# ==  readelf_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (32687, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1045984
# 가짜 데이터 다시 제거 후 최종 csv shape (1045961, 2)
# readelf_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  29
# 4. subtracting the rest finish (1080640, 2)
# 5. one hot encoding finish (1080640, 256)
# <class 'pandas.core.frame.DataFrame'> (1080640, 256)
# 6. Transforming ndarray data finish (1080640, 256)
# 7. before reshape data shape (1080640, 256)
# 8. after reshape data shape (33770, 32, 256)
# 9. test file load 완료
# ==  size_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33770, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1080640
# 가짜 데이터 다시 제거 후 최종 csv shape (1080637, 2)
# size_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1080384, 2)
# 5. one hot encoding finish (1080384, 256)
# <class 'pandas.core.frame.DataFrame'> (1080384, 256)
# 6. Transforming ndarray data finish (1080384, 256)
# 7. before reshape data shape (1080384, 256)
# 8. after reshape data shape (33762, 32, 256)
# 9. test file load 완료
# ==  strings_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33762, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1080384
# 가짜 데이터 다시 제거 후 최종 csv shape (1080365, 2)
# strings_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1256128, 2)
# 5. one hot encoding finish (1256128, 256)
# <class 'pandas.core.frame.DataFrame'> (1256128, 256)
# 6. Transforming ndarray data finish (1256128, 256)
# 7. before reshape data shape (1256128, 256)
# 8. after reshape data shape (39254, 32, 256)
# 9. test file load 완료
# ==  strip-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (39254, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1256128
# 가짜 데이터 다시 제거 후 최종 csv shape (1256105, 2)
# strip-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  15
# 4. subtracting the rest finish (25600, 2)
# 5. one hot encoding finish (25600, 256)
# <class 'pandas.core.frame.DataFrame'> (25600, 256)
# 6. Transforming ndarray data finish (25600, 256)
# 7. before reshape data shape (25600, 256)
# 8. after reshape data shape (800, 32, 256)
# 9. test file load 완료
# ==  sysinfo_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (800, 32, 256)
# predict 완료
# 전체 predict 정답 길이 25600
# 가짜 데이터 다시 제거 후 최종 csv shape (25583, 2)
# sysinfo_test_str.csv파일 csv저장 완료
