# %% [markdown]
# ## Predict bin_op2
# - <b>학습 모델 (gcc6_bincore_s32_h48_o2.h5) - binutils, coreutils 함수 시작점부터 32byte씩 hidden unit 48 개씩 최적화 O2 학습모델</b>
# - <b>테스트 bin_op2 , stirp 파일 각 EXE 파일들</b>

# %%
# model load
def load_trained_model(model_path):
    model = load_model(model_path)
    print('model load 완료')
    return model

# %%
def eval_load(data_path, file_name, model_sequence_length):
    # data load
    print('1. test data_load start')
    data = pd.read_csv(data_path + file_name, index_col=0)
    data.reset_index(inplace=True, drop=True)
    print('2. input data load and reset_index finish')

    # input sequence 로 나눔, 맨 뒤 나머지 빼기
    rest = len(data) % (model_sequence_length)
    print('3. rest data : ', rest)
    
    # 가짜 데이터 추가
    n = model_sequence_length - rest
    k = pd.DataFrame(columns=['bin','label'], data={'bin':[0]*n,'label':['0']*n})
    data = data.append(k)
    
    # data_sub_rest = data[:len(data) - rest]
    print('4. subtracting the rest finish', data.shape)

    # one hot encoding
#    encoder = LabelEncoder()
#    encoder.classes_ = 256
#    print('encoder.classes_', encoder.classes_)
#    data_onehot = encoder.fit_transform(data['bin'])
    data_onehot = pd.get_dummies(data['bin'], columns=np.arange(256))
    
    none_column = list(set(np.arange(256)).difference(set(data_onehot.columns)))
    for j in none_column:
    #    print(j)
        data_onehot[str(j)] = 0
    
    print('5. one hot encoding finish', data_onehot.shape)
    print(type(data_onehot), data_onehot.shape)
    
    data_ndarray = data_onehot.to_numpy() # data numpy 변환
    print('6. Transforming ndarray data finish', data_ndarray.shape)
    print('7. before reshape data shape', data_ndarray.shape)
    data_reshape = data_ndarray.reshape(-1, model_sequence_length, data_ndarray.shape[1])
    print('8. after reshape data shape', data_reshape.shape)
    print('9. test file load 완료')
    
    # reshape 된 data return
    return data_reshape, data, n

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder

# 파일 path 경로
model_path = 'model/gcc6_bincore_s32_h48_o2.h5'
data_path = 'data/strip/strip_gcc6_O2/'

import os
exe_file_list=os.listdir(data_path)
print("exe_file_list:{}".format(exe_file_list),'\n')

# model load
model = load_model(model_path)

# load test
for name in exe_file_list:
    test_data, data, n = eval_load(data_path, file_name=name, model_sequence_length=32)
    print('== ', name, '파일 predict 시작 ==')
    # model 모형 체크 및 데이터 read 체크
    model.summary()
    print('test_data.shape', test_data.shape)

    # model predict
    pr = model.predict(test_data)
    print('predict 완료')

    pr_ls = list(pr.flatten())
    print('전체 predict 정답 길이', len(pr_ls))
    pr_ls = list(map(lambda x:np.round(x), pr_ls))

    # 최종결과 데이터 
    result_data = pd.DataFrame(columns=['bin','label'])
    result_data['bin'] = data['bin'][:len(data)-n]
    result_data['label'] = pr_ls[:len(data)-n]

    # 다시 가짜 데이터 제거 후 최종 csv
    print('가짜 데이터 다시 제거 후 최종 csv shape', result_data.shape)
    result_data.to_csv('predict_result/bin_op2/'+name[:-4]+'_predict_result_op2.csv')
    print(name+'파일 csv저장 완료 \n\n')
# Out:
# exe_file_list:['addr2line_test_str.csv', 'ar_test_str.csv', 'as-new_test_str.csv', 'bfdtest1_test_str.csv', 'bfdtest2_test_str.csv', 'chew_test_str.csv', 'cxxfilt_test_str.csv', 'elfedit_test_str.csv', 'gentestdlls_test_str.csv', 'gprof_test_str.csv', 'ld-new_test_str.csv', 'nm-new_test_str.csv', 'objcopy_test_str.csv', 'objdump_test_str.csv', 'ranlib_test_str.csv', 'readelf_test_str.csv', 'size_test_str.csv', 'strings_test_str.csv', 'strip-new_test_str.csv', 'sysinfo_test_str.csv']
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  21
# 4. subtracting the rest finish (1116800, 2)
# 5. one hot encoding finish (1116800, 256)
# <class 'pandas.core.frame.DataFrame'> (1116800, 256)
# 6. Transforming ndarray data finish (1116800, 256)
# 7. before reshape data shape (1116800, 256)
# 8. after reshape data shape (34900, 32, 256)
# 9. test file load 완료
# ==  addr2line_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34900, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1116800
# 가짜 데이터 다시 제거 후 최종 csv shape (1116789, 2)
# addr2line_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1154560, 2)
# 5. one hot encoding finish (1154560, 256)
# <class 'pandas.core.frame.DataFrame'> (1154560, 256)
# 6. Transforming ndarray data finish (1154560, 256)
# 7. before reshape data shape (1154560, 256)
# 8. after reshape data shape (36080, 32, 256)
# 9. test file load 완료
# ==  ar_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (36080, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1154560
# 가짜 데이터 다시 제거 후 최종 csv shape (1154541, 2)
# ar_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  1
# 4. subtracting the rest finish (1874720, 2)
# 5. one hot encoding finish (1874720, 256)
# <class 'pandas.core.frame.DataFrame'> (1874720, 256)
# 6. Transforming ndarray data finish (1874720, 256)
# 7. before reshape data shape (1874720, 256)
# 8. after reshape data shape (58585, 32, 256)
# 9. test file load 완료
# ==  as-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (58585, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1874720
# 가짜 데이터 다시 제거 후 최종 csv shape (1874689, 2)
# as-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  25
# 4. subtracting the rest finish (1093440, 2)
# 5. one hot encoding finish (1093440, 256)
# <class 'pandas.core.frame.DataFrame'> (1093440, 256)
# 6. Transforming ndarray data finish (1093440, 256)
# 7. before reshape data shape (1093440, 256)
# 8. after reshape data shape (34170, 32, 256)
# 9. test file load 완료
# ==  bfdtest1_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34170, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1093440
# 가짜 데이터 다시 제거 후 최종 csv shape (1093433, 2)
# bfdtest1_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1093568, 2)
# 5. one hot encoding finish (1093568, 256)
# <class 'pandas.core.frame.DataFrame'> (1093568, 256)
# 6. Transforming ndarray data finish (1093568, 256)
# 7. before reshape data shape (1093568, 256)
# 8. after reshape data shape (34174, 32, 256)
# 9. test file load 완료
# ==  bfdtest2_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34174, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1093568
# 가짜 데이터 다시 제거 후 최종 csv shape (1093549, 2)
# bfdtest2_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  6
# 4. subtracting the rest finish (23584, 2)
# 5. one hot encoding finish (23584, 256)
# <class 'pandas.core.frame.DataFrame'> (23584, 256)
# 6. Transforming ndarray data finish (23584, 256)
# 7. before reshape data shape (23584, 256)
# 8. after reshape data shape (737, 32, 256)
# 9. test file load 완료
# ==  chew_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (737, 32, 256)
# predict 완료
# 전체 predict 정답 길이 23584
# 가짜 데이터 다시 제거 후 최종 csv shape (23558, 2)
# chew_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1111872, 2)
# 5. one hot encoding finish (1111872, 256)
# <class 'pandas.core.frame.DataFrame'> (1111872, 256)
# 6. Transforming ndarray data finish (1111872, 256)
# 7. before reshape data shape (1111872, 256)
# 8. after reshape data shape (34746, 32, 256)
# 9. test file load 완료
# ==  cxxfilt_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34746, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1111872
# 가짜 데이터 다시 제거 후 최종 csv shape (1111853, 2)
# cxxfilt_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  8
# 4. subtracting the rest finish (39360, 2)
# 5. one hot encoding finish (39360, 256)
# <class 'pandas.core.frame.DataFrame'> (39360, 256)
# 6. Transforming ndarray data finish (39360, 256)
# 7. before reshape data shape (39360, 256)
# 8. after reshape data shape (1230, 32, 256)
# 9. test file load 완료
# ==  elfedit_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (1230, 32, 256)
# predict 완료
# 전체 predict 정답 길이 39360
# 가짜 데이터 다시 제거 후 최종 csv shape (39336, 2)
# elfedit_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  0
# 4. subtracting the rest finish (6400, 2)
# 5. one hot encoding finish (6400, 256)
# <class 'pandas.core.frame.DataFrame'> (6400, 256)
# 6. Transforming ndarray data finish (6400, 256)
# 7. before reshape data shape (6400, 256)
# 8. after reshape data shape (200, 32, 256)
# 9. test file load 완료
# ==  gentestdlls_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (200, 32, 256)
# predict 완료
# 전체 predict 정답 길이 6400
# 가짜 데이터 다시 제거 후 최종 csv shape (6368, 2)
# gentestdlls_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1200352, 2)
# 5. one hot encoding finish (1200352, 256)
# <class 'pandas.core.frame.DataFrame'> (1200352, 256)
# 6. Transforming ndarray data finish (1200352, 256)
# 7. before reshape data shape (1200352, 256)
# 8. after reshape data shape (37511, 32, 256)
# 9. test file load 완료
# ==  gprof_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (37511, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1200352
# 가짜 데이터 다시 제거 후 최종 csv shape (1200333, 2)
# gprof_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  5
# 4. subtracting the rest finish (1918400, 2)
# 5. one hot encoding finish (1918400, 256)
# <class 'pandas.core.frame.DataFrame'> (1918400, 256)
# 6. Transforming ndarray data finish (1918400, 256)
# 7. before reshape data shape (1918400, 256)
# 8. after reshape data shape (59950, 32, 256)
# 9. test file load 완료
# ==  ld-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (59950, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1918400
# 가짜 데이터 다시 제거 후 최종 csv shape (1918373, 2)
# ld-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  25
# 4. subtracting the rest finish (1131968, 2)
# 5. one hot encoding finish (1131968, 256)
# <class 'pandas.core.frame.DataFrame'> (1131968, 256)
# 6. Transforming ndarray data finish (1131968, 256)
# 7. before reshape data shape (1131968, 256)
# 8. after reshape data shape (35374, 32, 256)
# 9. test file load 완료
# ==  nm-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (35374, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1131968
# 가짜 데이터 다시 제거 후 최종 csv shape (1131961, 2)
# nm-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  17
# 4. subtracting the rest finish (1292160, 2)
# 5. one hot encoding finish (1292160, 256)
# <class 'pandas.core.frame.DataFrame'> (1292160, 256)
# 6. Transforming ndarray data finish (1292160, 256)
# 7. before reshape data shape (1292160, 256)
# 8. after reshape data shape (40380, 32, 256)
# 9. test file load 완료
# ==  objcopy_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (40380, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1292160
# 가짜 데이터 다시 제거 후 최종 csv shape (1292145, 2)
# objcopy_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  21
# 4. subtracting the rest finish (2219360, 2)
# 5. one hot encoding finish (2219360, 256)
# <class 'pandas.core.frame.DataFrame'> (2219360, 256)
# 6. Transforming ndarray data finish (2219360, 256)
# 7. before reshape data shape (2219360, 256)
# 8. after reshape data shape (69355, 32, 256)
# 9. test file load 완료
# ==  objdump_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (69355, 32, 256)
# predict 완료
# 전체 predict 정답 길이 2219360
# 가짜 데이터 다시 제거 후 최종 csv shape (2219349, 2)
# objdump_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1154560, 2)
# 5. one hot encoding finish (1154560, 256)
# <class 'pandas.core.frame.DataFrame'> (1154560, 256)
# 6. Transforming ndarray data finish (1154560, 256)
# 7. before reshape data shape (1154560, 256)
# 8. after reshape data shape (36080, 32, 256)
# 9. test file load 완료
# ==  ranlib_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (36080, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1154560
# 가짜 데이터 다시 제거 후 최종 csv shape (1154537, 2)
# ranlib_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1049760, 2)
# 5. one hot encoding finish (1049760, 256)
# <class 'pandas.core.frame.DataFrame'> (1049760, 256)
# 6. Transforming ndarray data finish (1049760, 256)
# 7. before reshape data shape (1049760, 256)
# 8. after reshape data shape (32805, 32, 256)
# 9. test file load 완료
# ==  readelf_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (32805, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1049760
# 가짜 데이터 다시 제거 후 최종 csv shape (1049737, 2)
# readelf_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  21
# 4. subtracting the rest finish (1116992, 2)
# 5. one hot encoding finish (1116992, 256)
# <class 'pandas.core.frame.DataFrame'> (1116992, 256)
# 6. Transforming ndarray data finish (1116992, 256)
# 7. before reshape data shape (1116992, 256)
# 8. after reshape data shape (34906, 32, 256)
# 9. test file load 완료
# ==  size_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34906, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1116992
# 가짜 데이터 다시 제거 후 최종 csv shape (1116981, 2)
# size_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1116704, 2)
# 5. one hot encoding finish (1116704, 256)
# <class 'pandas.core.frame.DataFrame'> (1116704, 256)
# 6. Transforming ndarray data finish (1116704, 256)
# 7. before reshape data shape (1116704, 256)
# 8. after reshape data shape (34897, 32, 256)
# 9. test file load 완료
# ==  strings_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (34897, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1116704
# 가짜 데이터 다시 제거 후 최종 csv shape (1116681, 2)
# strings_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  17
# 4. subtracting the rest finish (1292160, 2)
# 5. one hot encoding finish (1292160, 256)
# <class 'pandas.core.frame.DataFrame'> (1292160, 256)
# 6. Transforming ndarray data finish (1292160, 256)
# 7. before reshape data shape (1292160, 256)
# 8. after reshape data shape (40380, 32, 256)
# 9. test file load 완료
# ==  strip-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (40380, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1292160
# 가짜 데이터 다시 제거 후 최종 csv shape (1292145, 2)
# strip-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  30
# 4. subtracting the rest finish (27232, 2)
# 5. one hot encoding finish (27232, 256)
# <class 'pandas.core.frame.DataFrame'> (27232, 256)
# 6. Transforming ndarray data finish (27232, 256)
# 7. before reshape data shape (27232, 256)
# 8. after reshape data shape (851, 32, 256)
# 9. test file load 완료
# ==  sysinfo_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (851, 32, 256)
# predict 완료
# 전체 predict 정답 길이 27232
# 가짜 데이터 다시 제거 후 최종 csv shape (27230, 2)
# sysinfo_test_str.csv파일 csv저장 완료
