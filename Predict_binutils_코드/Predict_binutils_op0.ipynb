# %% [markdown]
# ## Predict bin_op0
# - <b>학습 모델 (gcc6_bincore_s32_h48_o0.h5) - binutils, coreutils 함수 시작점부터 32byte씩 hidden unit 48 개씩 최적화 O0 학습모델</b>
# - <b>테스트 bin_op0 , stirp 파일 각 EXE 파일들</b>

# %%
# model load
def load_trained_model(model_path):
    model = load_model(model_path)
    print('model load 완료')
    return model

# %%
def eval_load(data_path, file_name, model_sequence_length):
    # data load
    print('1. test data_load start')
    data = pd.read_csv(data_path + file_name, index_col=0)
    data.reset_index(inplace=True, drop=True)
    print('2. input data load and reset_index finish')

    # input sequence 로 나눔, 맨 뒤 나머지 빼기
    rest = len(data) % (model_sequence_length)
    print('3. rest data : ', rest)
    
    # 가짜 데이터 추가
    n = model_sequence_length - rest
    k = pd.DataFrame(columns=['bin','label'], data={'bin':[0]*n,'label':['0']*n})
    data = data.append(k)
    
    # data_sub_rest = data[:len(data) - rest]
    print('4. subtracting the rest finish', data.shape)

    # one hot encoding
#    encoder = LabelEncoder()
#    encoder.classes_ = 256
#    print('encoder.classes_', encoder.classes_)
#    data_onehot = encoder.fit_transform(data['bin'])
    data_onehot = pd.get_dummies(data['bin'], columns=np.arange(256))
    
    none_column = list(set(np.arange(256)).difference(set(data_onehot.columns)))
    for j in none_column:
    #    print(j)
        data_onehot[str(j)] = 0
    
    print('5. one hot encoding finish', data_onehot.shape)
    print(type(data_onehot), data_onehot.shape)
    
    data_ndarray = data_onehot.to_numpy() # data numpy 변환
    print('6. Transforming ndarray data finish', data_ndarray.shape)
    print('7. before reshape data shape', data_ndarray.shape)
    data_reshape = data_ndarray.reshape(-1, model_sequence_length, data_ndarray.shape[1])
    print('8. after reshape data shape', data_reshape.shape)
    print('9. test file load 완료')
    
    # reshape 된 data return
    return data_reshape, data, n

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder

# 파일 path 경로
model_path = 'model/gcc6_bincore_s32_h48_o0.h5'
data_path = 'data/strip/strip_gcc6_O0/'

import os
exe_file_list=os.listdir(data_path)
print("exe_file_list:{}".format(exe_file_list),'\n')

# model load
model = load_model(model_path)

# load test
for name in exe_file_list:
    test_data, data, n = eval_load(data_path, file_name=name, model_sequence_length=32)
    print('== ', name, '파일 predict 시작 ==')
    # model 모형 체크 및 데이터 read 체크
    model.summary()
    print('test_data.shape', test_data.shape)

    # model predict
    pr = model.predict(test_data)
    print('predict 완료')

    pr_ls = list(pr.flatten())
    print('전체 predict 정답 길이', len(pr_ls))
    pr_ls = list(map(lambda x:np.round(x), pr_ls))

    # 최종결과 데이터 
    result_data = pd.DataFrame(columns=['bin','label'])
    result_data['bin'] = data['bin'][:len(data)-n]
    result_data['label'] = pr_ls[:len(data)-n]

    # 다시 가짜 데이터 제거 후 최종 csv
    print('가짜 데이터 다시 제거 후 최종 csv shape', result_data.shape)
    result_data.to_csv('predict_result/bin_op0/'+name[:-4]+'_predict_result_op0.csv')
    print(name+'파일 csv저장 완료 \n\n')
# Out:
# exe_file_list:['addr2line_test_str.csv', 'ar_test_str.csv', 'as-new_test_str.csv', 'bfdtest1_test_str.csv', 'bfdtest2_test_str.csv', 'chew_test_str.csv', 'cxxfilt_test_str.csv', 'elfedit_test_str.csv', 'gentestdlls_test_str.csv', 'gprof_test_str.csv', 'ld-new_test_str.csv', 'nm-new_test_str.csv', 'objcopy_test_str.csv', 'objdump_test_str.csv', 'ranlib_test_str.csv', 'readelf_test_str.csv', 'size_test_str.csv', 'strings_test_str.csv', 'strip-new_test_str.csv', 'sysinfo_test_str.csv']
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  13
# 4. subtracting the rest finish (1200000, 2)
# 5. one hot encoding finish (1200000, 256)
# <class 'pandas.core.frame.DataFrame'> (1200000, 256)
# 6. Transforming ndarray data finish (1200000, 256)
# 7. before reshape data shape (1200000, 256)
# 8. after reshape data shape (37500, 32, 256)
# 9. test file load 완료
# ==  addr2line_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (37500, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1200000
# 가짜 데이터 다시 제거 후 최종 csv shape (1199981, 2)
# addr2line_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  5
# 4. subtracting the rest finish (1238464, 2)
# 5. one hot encoding finish (1238464, 256)
# <class 'pandas.core.frame.DataFrame'> (1238464, 256)
# 6. Transforming ndarray data finish (1238464, 256)
# 7. before reshape data shape (1238464, 256)
# 8. after reshape data shape (38702, 32, 256)
# 9. test file load 완료
# ==  ar_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (38702, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1238464
# 가짜 데이터 다시 제거 후 최종 csv shape (1238437, 2)
# ar_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  1
# 4. subtracting the rest finish (1972768, 2)
# 5. one hot encoding finish (1972768, 256)
# <class 'pandas.core.frame.DataFrame'> (1972768, 256)
# 6. Transforming ndarray data finish (1972768, 256)
# 7. before reshape data shape (1972768, 256)
# 8. after reshape data shape (61649, 32, 256)
# 9. test file load 완료
# ==  as-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (61649, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1972768
# 가짜 데이터 다시 제거 후 최종 csv shape (1972737, 2)
# as-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  21
# 4. subtracting the rest finish (1176032, 2)
# 5. one hot encoding finish (1176032, 256)
# <class 'pandas.core.frame.DataFrame'> (1176032, 256)
# 6. Transforming ndarray data finish (1176032, 256)
# 7. before reshape data shape (1176032, 256)
# 8. after reshape data shape (36751, 32, 256)
# 9. test file load 완료
# ==  bfdtest1_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (36751, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1176032
# 가짜 데이터 다시 제거 후 최종 csv shape (1176021, 2)
# bfdtest1_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1176192, 2)
# 5. one hot encoding finish (1176192, 256)
# <class 'pandas.core.frame.DataFrame'> (1176192, 256)
# 6. Transforming ndarray data finish (1176192, 256)
# 7. before reshape data shape (1176192, 256)
# 8. after reshape data shape (36756, 32, 256)
# 9. test file load 완료
# ==  bfdtest2_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (36756, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1176192
# 가짜 데이터 다시 제거 후 최종 csv shape (1176169, 2)
# bfdtest2_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  2
# 4. subtracting the rest finish (25504, 2)
# 174
# 158
# 5. one hot encoding finish (25504, 256)
# <class 'pandas.core.frame.DataFrame'> (25504, 256)
# 6. Transforming ndarray data finish (25504, 256)
# 7. before reshape data shape (25504, 256)
# 8. after reshape data shape (797, 32, 256)
# 9. test file load 완료
# ==  chew_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (797, 32, 256)
# predict 완료
# 전체 predict 정답 길이 25504
# 가짜 데이터 다시 제거 후 최종 csv shape (25474, 2)
# chew_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  25
# 4. subtracting the rest finish (1194880, 2)
# 5. one hot encoding finish (1194880, 256)
# <class 'pandas.core.frame.DataFrame'> (1194880, 256)
# 6. Transforming ndarray data finish (1194880, 256)
# 7. before reshape data shape (1194880, 256)
# 8. after reshape data shape (37340, 32, 256)
# 9. test file load 완료
# ==  cxxfilt_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (37340, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1194880
# 가짜 데이터 다시 제거 후 최종 csv shape (1194873, 2)
# cxxfilt_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  3
# 4. subtracting the rest finish (42528, 2)
# 5. one hot encoding finish (42528, 256)
# <class 'pandas.core.frame.DataFrame'> (42528, 256)
# 6. Transforming ndarray data finish (42528, 256)
# 7. before reshape data shape (42528, 256)
# 8. after reshape data shape (1329, 32, 256)
# 9. test file load 완료
# ==  elfedit_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (1329, 32, 256)
# predict 완료
# 전체 predict 정답 길이 42528
# 가짜 데이터 다시 제거 후 최종 csv shape (42499, 2)
# elfedit_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  3
# 4. subtracting the rest finish (6976, 2)
# 132
# 142
# 143
# 145
# 19
# 21
# 153
# 25
# 157
# 30
# 162
# 167
# 169
# 170
# 43
# 174
# 177
# 189
# 61
# 190
# 202
# 211
# 213
# 217
# 218
# 219
# 239
# 5. one hot encoding finish (6976, 256)
# <class 'pandas.core.frame.DataFrame'> (6976, 256)
# 6. Transforming ndarray data finish (6976, 256)
# 7. before reshape data shape (6976, 256)
# 8. after reshape data shape (218, 32, 256)
# 9. test file load 완료
# ==  gentestdlls_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (218, 32, 256)
# predict 완료
# 전체 predict 정답 길이 6976
# 가짜 데이터 다시 제거 후 최종 csv shape (6947, 2)
# gentestdlls_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  1
# 4. subtracting the rest finish (1280128, 2)
# 5. one hot encoding finish (1280128, 256)
# <class 'pandas.core.frame.DataFrame'> (1280128, 256)
# 6. Transforming ndarray data finish (1280128, 256)
# 7. before reshape data shape (1280128, 256)
# 8. after reshape data shape (40004, 32, 256)
# 9. test file load 완료
# ==  gprof_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (40004, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1280128
# 가짜 데이터 다시 제거 후 최종 csv shape (1280097, 2)
# gprof_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (2024352, 2)
# 5. one hot encoding finish (2024352, 256)
# <class 'pandas.core.frame.DataFrame'> (2024352, 256)
# 6. Transforming ndarray data finish (2024352, 256)
# 7. before reshape data shape (2024352, 256)
# 8. after reshape data shape (63261, 32, 256)
# 9. test file load 완료
# ==  ld-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (63261, 32, 256)
# predict 완료
# 전체 predict 정답 길이 2024352
# 가짜 데이터 다시 제거 후 최종 csv shape (2024329, 2)
# ld-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  17
# 4. subtracting the rest finish (1215200, 2)
# 5. one hot encoding finish (1215200, 256)
# <class 'pandas.core.frame.DataFrame'> (1215200, 256)
# 6. Transforming ndarray data finish (1215200, 256)
# 7. before reshape data shape (1215200, 256)
# 8. after reshape data shape (37975, 32, 256)
# 9. test file load 완료
# ==  nm-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (37975, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1215200
# 가짜 데이터 다시 제거 후 최종 csv shape (1215185, 2)
# nm-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1386976, 2)
# 5. one hot encoding finish (1386976, 256)
# <class 'pandas.core.frame.DataFrame'> (1386976, 256)
# 6. Transforming ndarray data finish (1386976, 256)
# 7. before reshape data shape (1386976, 256)
# 8. after reshape data shape (43343, 32, 256)
# 9. test file load 완료
# ==  objcopy_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (43343, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1386976
# 가짜 데이터 다시 제거 후 최종 csv shape (1386953, 2)
# objcopy_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  17
# 4. subtracting the rest finish (2338176, 2)
# 5. one hot encoding finish (2338176, 256)
# <class 'pandas.core.frame.DataFrame'> (2338176, 256)
# 6. Transforming ndarray data finish (2338176, 256)
# 7. before reshape data shape (2338176, 256)
# 8. after reshape data shape (73068, 32, 256)
# 9. test file load 완료
# ==  objdump_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (73068, 32, 256)
# predict 완료
# 전체 predict 정답 길이 2338176
# 가짜 데이터 다시 제거 후 최종 csv shape (2338161, 2)
# objdump_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  5
# 4. subtracting the rest finish (1238464, 2)
# 5. one hot encoding finish (1238464, 256)
# <class 'pandas.core.frame.DataFrame'> (1238464, 256)
# 6. Transforming ndarray data finish (1238464, 256)
# 7. before reshape data shape (1238464, 256)
# 8. after reshape data shape (38702, 32, 256)
# 9. test file load 완료
# ==  ranlib_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (38702, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1238464
# 가짜 데이터 다시 제거 후 최종 csv shape (1238437, 2)
# ranlib_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1086592, 2)
# 5. one hot encoding finish (1086592, 256)
# <class 'pandas.core.frame.DataFrame'> (1086592, 256)
# 6. Transforming ndarray data finish (1086592, 256)
# 7. before reshape data shape (1086592, 256)
# 8. after reshape data shape (33956, 32, 256)
# 9. test file load 완료
# ==  readelf_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (33956, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1086592
# 가짜 데이터 다시 제거 후 최종 csv shape (1086569, 2)
# readelf_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  21
# 4. subtracting the rest finish (1200096, 2)
# 5. one hot encoding finish (1200096, 256)
# <class 'pandas.core.frame.DataFrame'> (1200096, 256)
# 6. Transforming ndarray data finish (1200096, 256)
# 7. before reshape data shape (1200096, 256)
# 8. after reshape data shape (37503, 32, 256)
# 9. test file load 완료
# ==  size_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (37503, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1200096
# 가짜 데이터 다시 제거 후 최종 csv shape (1200085, 2)
# size_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  9
# 4. subtracting the rest finish (1199904, 2)
# 5. one hot encoding finish (1199904, 256)
# <class 'pandas.core.frame.DataFrame'> (1199904, 256)
# 6. Transforming ndarray data finish (1199904, 256)
# 7. before reshape data shape (1199904, 256)
# 8. after reshape data shape (37497, 32, 256)
# 9. test file load 완료
# ==  strings_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (37497, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1199904
# 가짜 데이터 다시 제거 후 최종 csv shape (1199881, 2)
# strings_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  5
# 4. subtracting the rest finish (1386976, 2)
# 5. one hot encoding finish (1386976, 256)
# <class 'pandas.core.frame.DataFrame'> (1386976, 256)
# 6. Transforming ndarray data finish (1386976, 256)
# 7. before reshape data shape (1386976, 256)
# 8. after reshape data shape (43343, 32, 256)
# 9. test file load 완료
# ==  strip-new_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (43343, 32, 256)
# predict 완료
# 전체 predict 정답 길이 1386976
# 가짜 데이터 다시 제거 후 최종 csv shape (1386949, 2)
# strip-new_test_str.csv파일 csv저장 완료
#
#
# 1. test data_load start
# 2. input data load and reset_index finish
# 3. rest data :  29
# 4. subtracting the rest finish (28544, 2)
# 5. one hot encoding finish (28544, 256)
# <class 'pandas.core.frame.DataFrame'> (28544, 256)
# 6. Transforming ndarray data finish (28544, 256)
# 7. before reshape data shape (28544, 256)
# 8. after reshape data shape (892, 32, 256)
# 9. test file load 완료
# ==  sysinfo_test_str.csv 파일 predict 시작 ==
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 256)]         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 32, 96)            117120
# _________________________________________________________________
# time_distributed (TimeDistri (None, 32, 1)             97
# =================================================================
# Total params: 117,217
# Trainable params: 117,217
# Non-trainable params: 0
# _________________________________________________________________
# test_data.shape (892, 32, 256)
# predict 완료
# 전체 predict 정답 길이 28544
# 가짜 데이터 다시 제거 후 최종 csv shape (28541, 2)
# sysinfo_test_str.csv파일 csv저장 완료
